# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据集
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)

#每个批次的大小
batch_size = 64
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#二次代价函数
#loss = tf.losses.mean_squared_error(y,prediction)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = prediction))

#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    #epoch：所有数据训练一次，就是一个epoch周期
    for epoch in range(20):
        #batch：一般为32，64个数据
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.8326
# Iter 1,Testing Accuracy 0.9013
# Iter 2,Testing Accuracy 0.9072
# Iter 3,Testing Accuracy 0.9094
# Iter 4,Testing Accuracy 0.9133
# Iter 5,Testing Accuracy 0.9157
# Iter 6,Testing Accuracy 0.9166
# Iter 7,Testing Accuracy 0.9173
# Iter 8,Testing Accuracy 0.9185
# Iter 9,Testing Accuracy 0.9189
# Iter 10,Testing Accuracy 0.9196
# Iter 11,Testing Accuracy 0.9214
# Iter 12,Testing Accuracy 0.9216
# Iter 13,Testing Accuracy 0.9219
# Iter 14,Testing Accuracy 0.9216
# Iter 15,Testing Accuracy 0.9228
# Iter 16,Testing Accuracy 0.9224
# Iter 17,Testing Accuracy 0.9225
# Iter 18,Testing Accuracy 0.9243
# Iter 19,Testing Accuracy 0.924
# Iter 20,Testing Accuracy 0.9248
# Iter 21,Testing Accuracy 0.9237
# Iter 22,Testing Accuracy 0.9248
# Iter 23,Testing Accuracy 0.9248
# Iter 24,Testing Accuracy 0.9255
# Iter 25,Testing Accuracy 0.9255
# Iter 26,Testing Accuracy 0.9253
# Iter 27,Testing Accuracy 0.9256
# Iter 28,Testing Accuracy 0.9267
# Iter 29,Testing Accuracy 0.9258
# Iter 30,Testing Accuracy 0.9276
# Iter 31,Testing Accuracy 0.9253
# Iter 32,Testing Accuracy 0.9275
# Iter 33,Testing Accuracy 0.9272
# Iter 34,Testing Accuracy 0.9275
# Iter 35,Testing Accuracy 0.9264
# Iter 36,Testing Accuracy 0.9267
# Iter 37,Testing Accuracy 0.9272
# Iter 38,Testing Accuracy 0.9269
# Iter 39,Testing Accuracy 0.9283
# Iter 40,Testing Accuracy 0.9284
# Iter 41,Testing Accuracy 0.9283
# Iter 42,Testing Accuracy 0.9278
# Iter 43,Testing Accuracy 0.9282
# Iter 44,Testing Accuracy 0.9286
# Iter 45,Testing Accuracy 0.9278
# Iter 46,Testing Accuracy 0.9278
# Iter 47,Testing Accuracy 0.9274
# Iter 48,Testing Accuracy 0.928
# Iter 49,Testing Accuracy 0.9284
# Iter 50,Testing Accuracy 0.9288
# Iter 51,Testing Accuracy 0.928
# Iter 52,Testing Accuracy 0.9289
# Iter 53,Testing Accuracy 0.9281
# Iter 54,Testing Accuracy 0.9288
# Iter 55,Testing Accuracy 0.9276
# Iter 56,Testing Accuracy 0.9283
# Iter 57,Testing Accuracy 0.9282
# Iter 58,Testing Accuracy 0.9286
# Iter 59,Testing Accuracy 0.9279
# Iter 60,Testing Accuracy 0.9286
# Iter 61,Testing Accuracy 0.9279
# Iter 62,Testing Accuracy 0.9282
# Iter 63,Testing Accuracy 0.9279
# Iter 64,Testing Accuracy 0.9289
# Iter 65,Testing Accuracy 0.928
# Iter 66,Testing Accuracy 0.9293
# Iter 67,Testing Accuracy 0.9283
# Iter 68,Testing Accuracy 0.9292
# Iter 69,Testing Accuracy 0.9288
# Iter 70,Testing Accuracy 0.9284
# Iter 71,Testing Accuracy 0.9285
# Iter 72,Testing Accuracy 0.9279
# Iter 73,Testing Accuracy 0.9281
# Iter 74,Testing Accuracy 0.9282
# Iter 75,Testing Accuracy 0.9289
# Iter 76,Testing Accuracy 0.9288
# Iter 77,Testing Accuracy 0.929
# Iter 78,Testing Accuracy 0.9288
# Iter 79,Testing Accuracy 0.9286
# Iter 80,Testing Accuracy 0.9286
# Iter 81,Testing Accuracy 0.9286
# Iter 82,Testing Accuracy 0.9291
# Iter 83,Testing Accuracy 0.9282
# Iter 84,Testing Accuracy 0.9285
# Iter 85,Testing Accuracy 0.928
# Iter 86,Testing Accuracy 0.9291
# Iter 87,Testing Accuracy 0.9287
# Iter 88,Testing Accuracy 0.9292
# Iter 89,Testing Accuracy 0.9287
# Iter 90,Testing Accuracy 0.9293
# Iter 91,Testing Accuracy 0.929
# Iter 92,Testing Accuracy 0.9285
# Iter 93,Testing Accuracy 0.9285
# Iter 94,Testing Accuracy 0.9288
# Iter 95,Testing Accuracy 0.9282
# Iter 96,Testing Accuracy 0.929
# Iter 97,Testing Accuracy 0.9291
# Iter 98,Testing Accuracy 0.9294
# Iter 99,Testing Accuracy 0.9289
# Iter 100,Testing Accuracy 0.9293
# Iter 101,Testing Accuracy 0.9287
# Iter 102,Testing Accuracy 0.93
# Iter 103,Testing Accuracy 0.9292
# Iter 104,Testing Accuracy 0.9283
# Iter 105,Testing Accuracy 0.9288
# Iter 106,Testing Accuracy 0.9294
# Iter 107,Testing Accuracy 0.929
# Iter 108,Testing Accuracy 0.9296
# Iter 109,Testing Accuracy 0.9297
# Iter 110,Testing Accuracy 0.93
# Iter 111,Testing Accuracy 0.9294
# Iter 112,Testing Accuracy 0.9293
# Iter 113,Testing Accuracy 0.9291
# Iter 114,Testing Accuracy 0.9299
# Iter 115,Testing Accuracy 0.9296
# Iter 116,Testing Accuracy 0.9294
# Iter 117,Testing Accuracy 0.9294
# Iter 118,Testing Accuracy 0.9297
# Iter 119,Testing Accuracy 0.9284
# Iter 120,Testing Accuracy 0.9297
# Iter 121,Testing Accuracy 0.9292
# Iter 122,Testing Accuracy 0.9289
# Iter 123,Testing Accuracy 0.9298
# Iter 124,Testing Accuracy 0.9296
# Iter 125,Testing Accuracy 0.9292
# Iter 126,Testing Accuracy 0.9296
# Iter 127,Testing Accuracy 0.9291
# Iter 128,Testing Accuracy 0.9293
# Iter 129,Testing Accuracy 0.9297
# Iter 130,Testing Accuracy 0.9295
# Iter 131,Testing Accuracy 0.9295
# Iter 132,Testing Accuracy 0.93
# Iter 133,Testing Accuracy 0.9298
# Iter 134,Testing Accuracy 0.9297
# Iter 135,Testing Accuracy 0.9298
# Iter 136,Testing Accuracy 0.9294
# Iter 137,Testing Accuracy 0.9297
# Iter 138,Testing Accuracy 0.9296
# Iter 139,Testing Accuracy 0.9293
# Iter 140,Testing Accuracy 0.93
# Iter 141,Testing Accuracy 0.9299
# Iter 142,Testing Accuracy 0.9293
# Iter 143,Testing Accuracy 0.9301
# Iter 144,Testing Accuracy 0.9297
# Iter 145,Testing Accuracy 0.9303
# Iter 146,Testing Accuracy 0.9294
# Iter 147,Testing Accuracy 0.9296
# Iter 148,Testing Accuracy 0.929
# Iter 149,Testing Accuracy 0.9294
# Iter 150,Testing Accuracy 0.9293
# Iter 151,Testing Accuracy 0.93
# Iter 152,Testing Accuracy 0.9294
# Iter 153,Testing Accuracy 0.9302
# Iter 154,Testing Accuracy 0.9303
# Iter 155,Testing Accuracy 0.9293
# Iter 156,Testing Accuracy 0.93
# Iter 157,Testing Accuracy 0.9303
# Iter 158,Testing Accuracy 0.93
# Iter 159,Testing Accuracy 0.9295
# Iter 160,Testing Accuracy 0.9304
# Iter 161,Testing Accuracy 0.9292
# Iter 162,Testing Accuracy 0.9297
# Iter 163,Testing Accuracy 0.9301
# Iter 164,Testing Accuracy 0.9299
# Iter 165,Testing Accuracy 0.9295
# Iter 166,Testing Accuracy 0.9291
# Iter 167,Testing Accuracy 0.9294
# Iter 168,Testing Accuracy 0.9296
# Iter 169,Testing Accuracy 0.9304
# Iter 170,Testing Accuracy 0.9292
# Iter 171,Testing Accuracy 0.9304
# Iter 172,Testing Accuracy 0.9297
# Iter 173,Testing Accuracy 0.9299
# Iter 174,Testing Accuracy 0.9299
# Iter 175,Testing Accuracy 0.9298
# Iter 176,Testing Accuracy 0.9301
# Iter 177,Testing Accuracy 0.9296
# Iter 178,Testing Accuracy 0.9292
# Iter 179,Testing Accuracy 0.9298
# Iter 180,Testing Accuracy 0.9295
# Iter 181,Testing Accuracy 0.9295
# Iter 182,Testing Accuracy 0.9297
# Iter 183,Testing Accuracy 0.9299
# Iter 184,Testing Accuracy 0.9299
# Iter 185,Testing Accuracy 0.9298
# Iter 186,Testing Accuracy 0.9301
# Iter 187,Testing Accuracy 0.9297
# Iter 188,Testing Accuracy 0.9294
# Iter 189,Testing Accuracy 0.9296
# Iter 190,Testing Accuracy 0.9297
# Iter 191,Testing Accuracy 0.9295
# Iter 192,Testing Accuracy 0.9297
# Iter 193,Testing Accuracy 0.9297
# Iter 194,Testing Accuracy 0.9299
# Iter 195,Testing Accuracy 0.9296
# Iter 196,Testing Accuracy 0.9301
# Iter 197,Testing Accuracy 0.93
# Iter 198,Testing Accuracy 0.9292
# Iter 199,Testing Accuracy 0.9298
