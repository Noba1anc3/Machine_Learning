# %% [markdown]
# 基本数据类型：
#
# integer
# 整型（整数类型）
# 1
# 5
# 100
#
# float
# 浮点型（小数）
# 0.1
# 3.1415
# 189.153
#
# string
# 字符串型
# "This is a string"
# "123"
# '123'

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
print("hello world")
print("hello world")
# Out:
# hello world
# hello world
# hello world

# %%
print "hello world"
# Out:
#   File "<ipython-input-2-d0db7f9aba35>", line 1
#     print "hello world"
#                       ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(hello world)
# Out:
#   File "<ipython-input-3-63868289fc00>", line 1
#     print(hello world)
#                     ^
# SyntaxError: invalid syntax

# %%
print(“hello world”)
# Out:
#   File "<ipython-input-4-dccc2e36aac4>", line 1
#     print(“hello world”)
#                ^
# SyntaxError: invalid character in identifier

# %%
print('hello world')
# Out:
# hello world

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
print("hello" + 123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4a197b7c56f0> in <module>()
# ----> 1 print("hello" + 123)
#
# TypeError: Can't convert 'int' object to str implicitly

# %%
print("hello" + "123")
# Out:
# hello123

# %%
print("hello" + str(123))
# Out:
# hello123

# %%
print(1+2)
# Out:
# 3

# %%
print('1+2')
# Out:
# 1+2

# %%
print(int('1')+2)
# Out:
# 3

# %%
print(int('1.5')+2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6c694898d605> in <module>()
# ----> 1 print(int('1.5')+2)
#
# ValueError: invalid literal for int() with base 10: '1.5'

# %%
print(float('1.5')+2)
# Out:
# 3.5

# %%
print("hello world" 123")
# Out:
#   File "<ipython-input-17-b0d10b0e9fbe>", line 1
#     print("hello world" 123")
#                           ^
# SyntaxError: invalid syntax
