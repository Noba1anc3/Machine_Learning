# %%
a_list = [1,2,3,4,5]

d = {'pen':7,'apple':3,'applepen':10} #Key:Value,键：值
d2 = {1:'a',5:'b',2:'d'}
d3 = {1.2:3,'a':3.5,1:'aaa'}

print(d)
print(d2)
print(d3)
# Out:
# {'pen': 7, 'apple': 3, 'applepen': 10}
# {1: 'a', 2: 'd', 5: 'b'}
# {1.2: 3, 'a': 3.5, 1: 'aaa'}

# %%
print(d['apple'])
# Out:
# 3

# %%
print(d2[2])
# Out:
# d

# %%
print(d3[1.2])
# Out:
# 3

# %%
d4 = {'a':[1,2,3,4],'b':(1,2,3,4),'c':{'aa':1,'bb':2}}
print(d4)
# Out:
# {'c': {'aa': 1, 'bb': 2}, 'a': [1, 2, 3, 4], 'b': (1, 2, 3, 4)}

# %%
print(d4['c']['aa'])
# Out:
# 1

# %%
d['pen'] = 10 #修改Key对应的Value
print(d)
# Out:
# {'pen': 10, 'apple': 3, 'applepen': 10}

# %%
d['pineapple'] = 3 #新增一个key：value对
print(d)
# Out:
# {'pen': 10, 'apple': 3, 'pineapple': 3, 'applepen': 10}

# %%
del d['pineapple'] #删除一个键值对
print(d)
# Out:
# {'pen': 10, 'apple': 3, 'applepen': 10}

# %%
for key,value in d.items():#遍历整个字典的键值对
    print('key:',key,'\t','value:',value)
# Out:
# key: pen 	 value: 10
# key: apple 	 value: 3
# key: applepen 	 value: 10

# %%
for key in d.keys():  #遍历整个字典的键
    print('key:',key)
# Out:
# key: pen
# key: apple
# key: applepen

# %%
for value in d.values(): #遍历整个字典的值
    print('values:',value)
# Out:
# values: 10
# values: 3
# values: 10

# %%
for key in sorted(d2.keys()):
    print('key:',key)
# Out:
# key: 1
# key: 2
# key: 5
