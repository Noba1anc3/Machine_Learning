# %%
a_tuple = (1,2,30,30,4,5)
b_tuple = 1,2,30,30,4,5
print(a_tuple)
print(b_tuple)
# Out:
# (1, 2, 30, 30, 4, 5)
# (1, 2, 30, 30, 4, 5)

# %%
print(a_tuple[1])
# Out:
# 2

# %%
print(a_tuple[1:4])
# Out:
# (2, 30, 30)

# %%
print(a_tuple.count(30))
# Out:
# 2

# %%
for i in a_tuple:
    print(i)
# Out:
# 1
# 2
# 30
# 30
# 4
# 5

# %%
a_tuple.sort()
print(a_tuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3f40c34ad340> in <module>()
# ----> 1 a_tuple.sort()
#       2 print(a_tuple)
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
a_tuple.append(200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ea1ad90586e7> in <module>()
# ----> 1 a_tuple.append(200)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a_tuple = (1,2,3,4)
print(a_tuple)
# Out:
# (1, 2, 3, 4)
