# %%
def function(): #定义一个函数
    a = 1
    b = 2 
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

# %%
function()
# Out:
# a= 1
# b= 2
# c= 3
# a+b= 3

# %%
def function2(a,b): #定义一个带参数的函数，a，b为形参(局部变量)，只有在函数的内部发生作用
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

# %%
function2(10,20)
# Out:
# a= 10
# b= 20
# c= 30
# a+b= 30

# %%
function2(123,222)
# Out:
# a= 123
# b= 222
# c= 345
# a+b= 345

# %%
a2 = 30
b2 = 40
function2(a2,b2)
# Out:
# a= 30
# b= 40
# c= 70
# a+b= 70

# %%
print(a2,b2)
# Out:
# 30 40

# %%
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d206aaf65b2a> in <module>()
# ----> 1 print(a,b)
#
# NameError: name 'a' is not defined

# %%
function2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c21a446f4e1c> in <module>()
# ----> 1 function2()
#
# TypeError: function2() missing 2 required positional arguments: 'a' and 'b'

# %%
function2(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6c3aeaf81148> in <module>()
# ----> 1 function2(100)
#
# TypeError: function2() missing 1 required positional argument: 'b'

# %%
def function3(a=10,b=20): #设置默认值
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

# %%
function3()
# Out:
# a= 10
# b= 20
# c= 30
# a+b= 30

# %%
function3(50)
# Out:
# a= 50
# b= 20
# c= 70
# a+b= 70

# %%
function3(20,30)
# Out:
# a= 20
# b= 30
# c= 50
# a+b= 50

# %%
def function4(a,b=20): #设置默认值
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

# %%
function4()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-53b17406922d> in <module>()
# ----> 1 function4()
#
# TypeError: function4() missing 1 required positional argument: 'a'

# %%
function4(50)
# Out:
# a= 50
# b= 20
# c= 70
# a+b= 70

# %%
function4(100,200)
# Out:
# a= 100
# b= 200
# c= 300
# a+b= 300

# %%
def function3(a=10,b=20): #设置默认值
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

a = 1000
function3() #如果函数中的局部变量与全局变量重名，默认使用局部变量
# Out:
# a= 10
# b= 20
# c= 30
# a+b= 30

# %%
def function5(b=20): #设置默认值
    global a   #使用全局变量
    c = a + b
    print('a=',a)
    print('b=',b)
    print('c=',c)
    print('a+b=',c)

# %%
function5()
# Out:
# a= 1000
# b= 20
# c= 1020
# a+b= 1020

# %%
# 有返回值的函数
def add(a,b):
    c = a + b
    return c

# %%
d = add(23,45)
print(d)
# Out:
# 68
